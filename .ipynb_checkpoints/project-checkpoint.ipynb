# %%
import pandas as pd

# %%
df=pd.read_csv("sales_data.csv")
df
# Out:
#      OrderID   OrderDate   Product         Category Region  Quantity  \
# 0          1  2022-04-13  Keyboard      Electronics   East         6
# 1          2  2023-03-12   Monitor  Office Supplies  North         5
# 2          3  2024-05-10   Printer  Office Supplies   East         6
# 3          4  2022-09-28    Laptop      Electronics  South         7
# 4          5  2022-04-17     Mouse      Accessories   East         5
# ..       ...         ...       ...              ...    ...       ...
# 995      996  2022-01-10   Printer      Electronics  North         1
# 996      997  2024-04-03    Tablet      Accessories  South         2
# 997      998  2024-03-08     Mouse      Electronics   East         2
# 998      999  2022-08-30    Camera  Office Supplies  South         3
# 999     1000  2022-09-08     Mouse      Electronics  North         7
#
#      UnitPrice  TotalSales
# 0          707        4242
# 1         1391        6955
# 2          785        4710
# 3         1442       10094
# 4          433        2165
# ..         ...         ...
# 995        632         632
# 996       1577        3154
# 997        925        1850
# 998        420        1260
# 999        152        1064
#
# [1000 rows x 8 columns]

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])
df['Year']=df['OrderDate'].dt.year
df['Month']= df['OrderDate'].dt.month
df['Day']=df['OrderDate'] .dt. day
df['totalsales'] =df['Quantity']*df['UnitPrice']
df
# Out:
#      OrderID  OrderDate   Product         Category Region  Quantity  \
# 0          1 2022-04-13  Keyboard      Electronics   East         6
# 1          2 2023-03-12   Monitor  Office Supplies  North         5
# 2          3 2024-05-10   Printer  Office Supplies   East         6
# 3          4 2022-09-28    Laptop      Electronics  South         7
# 4          5 2022-04-17     Mouse      Accessories   East         5
# ..       ...        ...       ...              ...    ...       ...
# 995      996 2022-01-10   Printer      Electronics  North         1
# 996      997 2024-04-03    Tablet      Accessories  South         2
# 997      998 2024-03-08     Mouse      Electronics   East         2
# 998      999 2022-08-30    Camera  Office Supplies  South         3
# 999     1000 2022-09-08     Mouse      Electronics  North         7
#
#      UnitPrice  TotalSales  Year  Month  Day  totalsales
# 0          707        4242  2022      4   13        4242
# 1         1391        6955  2023      3   12        6955
# 2          785        4710  2024      5   10        4710
# 3         1442       10094  2022      9   28       10094
# 4          433        2165  2022      4   17        2165
# ..         ...         ...   ...    ...  ...         ...
# 995        632         632  2022      1   10         632
# 996       1577        3154  2024      4    3        3154
# 997        925        1850  2024      3    8        1850
# 998        420        1260  2022      8   30        1260
# 999        152        1064  2022      9    8        1064
#
# [1000 rows x 12 columns]

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['totalsales'] ,bins=50,kde=True)
plt.title("electonic")
plt.show()

# %%
sns.barplot (x="Category", y="Quantity",data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Quantity'>

# %%
monthly_sales=df.groupby(df['OrderDate'].dt.to_period("M"))['TotalSales'].sum()

plt.figure(figsize=(12,6))
monthly_sales.plot(kind="line", marker="o")
plt.title("monthly sales trend")
plt.xlabel("month")
plt.ylabel("Total Sales")
plt.show()

# %%
sns.barplot (x="Region", y="TotalSales", data=df)
# Out:
# <Axes: xlabel='Region', ylabel='TotalSales'>

# %%
plt.figure(figsize=(8,5))
numeric_df=df.select_dtypes(include=['int64','float64'])
sns.heatmap(numeric_df.corr(),annot=True,cmap="coolwarm")
plt.title("correlation heatmap")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv("data_series.csv")
df
# Out:
#       Student_ID  Math  Science  English  Arts  Computer  Social_Studies   PE  \
# 0              1    57       51       77    68        92              80   82
# 1              2    52       77       53    68        55              72  100
# 2              3    92       73       57    73        76              72   99
# 3              4    86       86      100    92        72              58   55
# 4              5    59       71       82    53        56              64   93
# ...          ...   ...      ...      ...   ...       ...             ...  ...
# 9995        9996    50       70       89    58        77              75   50
# 9996        9997    95       68       75    83        54              76   53
# 9997        9998    72       93       75    64        56              64   92
# 9998        9999    86       79       98    68        82              86   82
# 9999       10000    63       75       74    71        82              55   76
#
#         Interest  Strength      Recommended_Career          Subjects_Needed
# 0         Coding  Computer                  Doctor         Biology, Science
# 1       Robotics        PE  Sports Physiotherapist              PE, Biology
# 2     Healthcare        PE    Fitness Entrepreneur     PE, Business Studies
# 3     Leadership   English              Journalist  English, Social Studies
# 4         Nature        PE  Sports Physiotherapist              PE, Biology
# ...          ...       ...                     ...                      ...
# 9995    Robotics   English         Content Creator                  English
# 9996     History      Math    Blockchain Developer           Computer, Math
# 9997     Finance   Science    Blockchain Developer           Computer, Math
# 9998     Writing   English              Journalist  English, Social Studies
# 9999  Leadership  Computer      Software Developer           Computer, Math
#
# [10000 rows x 12 columns]

# %%
df.head()
# Out:
#    Student_ID  Math  Science  English  Arts  Computer  Social_Studies   PE  \
# 0           1    57       51       77    68        92              80   82
# 1           2    52       77       53    68        55              72  100
# 2           3    92       73       57    73        76              72   99
# 3           4    86       86      100    92        72              58   55
# 4           5    59       71       82    53        56              64   93
#
#      Interest  Strength      Recommended_Career          Subjects_Needed
# 0      Coding  Computer                  Doctor         Biology, Science
# 1    Robotics        PE  Sports Physiotherapist              PE, Biology
# 2  Healthcare        PE    Fitness Entrepreneur     PE, Business Studies
# 3  Leadership   English              Journalist  English, Social Studies
# 4      Nature        PE  Sports Physiotherapist              PE, Biology
