# %%
import pandas as pd

# %%
df=pd.read_csv("Employee_Salary_Dataset.csv")

# %%
d["country"]="india"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d["country"]="india"
#
# NameError: name 'd' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head(10)
# Out:
#    ID  Experience_Years  Age  Gender   Salary
# 0   1                 5   28  Female   250000
# 1   2                 1   21    Male    50000
# 2   3                 3   23    male   170000
# 3   4                 2   22    Male    25000
# 4   5                 1   17    Male    10000
# 5   6                25   62    Male  5001000
# 6   7                19   54  Female   800000
# 7   8                 2   21  Female     9000
# 8   9                10   36  Female    61500
# 9  10                15   54  Female   650000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
b=df.columns

# %%
b
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
df.shape
# Out:
# (35, 5)

# %%
d=df[df["Age"]]
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 d=df[df["Age"]]
#       2 d
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
d
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23    male    170000
# 3    4                 2   22    Male     25000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# 19  20                10   36    Male    330000
# ...

# %%
b=df[df["Age"]>60]

# %%
b
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 5    6                25   62    Male   5001000
# 27  28                27   62  Female  10000000

# %%
import pandas as pd

# %%
df=pd.read_csv("people-1000.csv")

# %%
df
# Out:
#      Index          User Id   First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe       Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed           Jo    Rivers  Female
# 2        3  810Ce0F276Badec       Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1      Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9      Lindsey      Rice  Female
# ..     ...              ...          ...       ...     ...
# 145    146  979A626e5F115f2       Teresa      Page    Male
# 146    147  009E1accabB9Af6        Randy    Tanner  Female
# 147    148  a9E3b490AE3B346        Joann    Fuller    Male
# 148    149  Ab0bbcE993E23c7  Christopher     Braun  Female
# 149    150  5627680A2Ca214B        Malik   Summers    Male
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
a=df.head(20)

# %%
a
# Out:
#     Index          User Id First Name Last Name     Sex  \
# 0       1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1       2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2       3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3       4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4       5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# 5       6  aF75e6dDEBC5b66     Sherry  Caldwell    Male
# 6       7  efeb05c7Cc94EA3     Ernest   Hoffman    Male
# 7       8  fb1BF3FED57E9d7      Doris  Andersen    Male
# 8       9  421fAB9a3b98F30     Cheryl      Mays    Male
# 9      10  4A42Fe10dB717CB      Harry  Mitchell    Male
# 10     11  44FAA9C3CE8DB2B      Casey     Ayala    Male
# 11     12  86cCc6417942b4B       Sara      Huff    Male
# 12     13  CDA21B6e83Cafe3      Eddie    Barnes  Female
# 13     14  1CC30c5F204332e      Ralph      Lowe  Female
# 14     15  b4bE3BfBfeBC29e  Priscilla     Davis    Male
# 15     16  bFCFDdE5491caE8      Carly    Abbott  Female
# ...

# %%
b=df.tail(20)

# %%
b
# Out:
#      Index          User Id   First Name   Last Name     Sex  \
# 130    131  aE16A3c90AC05dB        April      Hebert    Male
# 131    132  8CA86e8FcACeE4D        Peter        Long    Male
# 132    133  99d1Fb3608ACF2A    Christina      Carter  Female
# 133    134  4eB6A9cb84BF51B        David    Faulkner  Female
# 134    135  B43EAF7bc56967C       Willie    Arellano  Female
# 135    136  6e07e8F150DeB82        Traci        Sosa    Male
# 136    137  f781EbEb7FDBE35   Alexandria     Burgess    Male
# 137    138  B9506A7DdC58b34       Manuel      Castro    Male
# 138    139  be4B0DFd06FFF1D       Nathan       Glenn    Male
# 139    140  7d3402dB0D0d2ae       Hailey     Aguirre    Male
# 140    141  9BEeD41BDC4ca32       Arthur       Lyons  Female
# 141    142  B81eeD3F7e13A2e        Alexa  Washington  Female
# 142    143  cF20CcFDD4E8733        Jorge       Wells  Female
# 143    144  0c7fc0bFd703d8e        Oscar     Camacho  Female
# ...

# %%
c=df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          150 non-null    int64
#  1   User Id        150 non-null    object
#  2   First Name     150 non-null    object
#  3   Last Name      150 non-null    object
#  4   Sex            150 non-null    object
#  5   Email          150 non-null    object
#  6   Phone          150 non-null    object
#  7   Date of birth  150 non-null    object
#  8   Job Title      150 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 10.7+ KB

# %%
d=df.describe()

# %%
d
# Out:
#             Index
# count  150.000000
# mean    75.500000
# std     43.445368
# min      1.000000
# 25%     38.250000
# 50%     75.500000
# 75%    112.750000
# max    150.000000

# %%
e=df.columns

# %%
e
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
f=df.shape

# %%
f
# Out:
# (150, 9)

# %%
g=df.loc()

# %%
g

# %%
h=df.iloc()

# %%
h

# %%
i=df["Job Tittle"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Job Tittle'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ...

# %%
j=df.sort_values("Email")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12652\67997439.py in ?()
# ----> 1 j=df.sort_values("Email")
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7192             )
#    7193         elif len(by):
#    7194             # len(by) == 1
#    7195
# -> 7196             k = self._get_label_or_level_values(by[0], axis=axis)
#    7197
#    7198             # need to rewrap column in Series to apply key function
#    7199             if key is not None:
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
# ...

# %%
j
# Out:
#      Index          User Id  First Name Last Name     Sex  \
# 143    144  0c7fc0bFd703d8e       Oscar   Camacho  Female
# 46      47  eEF6Cf6C10b1446        Erik   Rosales  Female
# 7        8  fb1BF3FED57E9d7       Doris  Andersen    Male
# 19      20  462EF46dcaab6EC       Perry   Mcmahon  Female
# 118    119  736A87324dd4E3b        Neil    Sawyer    Male
# ..     ...              ...         ...       ...     ...
# 139    140  7d3402dB0D0d2ae      Hailey   Aguirre    Male
# 129    130  6b03e33eEddCFC7      Andrew    Holden    Male
# 69      70  D88FB59Ed3efac7  Alexandria   Mcguire  Female
# 91      92  87bf311C37DC95E      Jaclyn    Mclean    Male
# 3        4  BF2a889C00f0cE1     Whitney    Hooper    Male
#
#                            Email               Phone Date of birth  \
# 143    albertstanton@example.net        853.032.2083    1910-08-23
# 46       alejandro41@example.net       (412)388-9715    2019-05-06
# ...
